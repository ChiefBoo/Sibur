# %% [markdown]
# #Графики и гистограммы

# %%
import random
import numpy as np

# %%
""" Main class """
import time
import matplotlib.pyplot as plt
import random


def main():

    print('Input count of iter number graph: ')
    count = int(input())
    count_vertex = 100
    interval = 100
    x = [i for i in range(count_vertex, count*count_vertex+1, count_vertex)]   #[100,200,...]
    #print(x)
    count_1_center = [0 for i in range(count)]

    count_2_center = [0 for i in range(count)]

    count_1_centroid = [0 for i in range(count)]

    count_2_centroid = [0 for i in range(count)]

    
    #count_graph = 10

    for i in range(count):
        
        cent_1 = 0
        cent_2 = 0
        cend_1 = 0
        cend_2 = 0

        print('iter - ', i+1)
        for j in range(x[i]):
            #print('count_vertex =' ,count_vertex)
            #rand_top = random.randint(0, count_vertex-1)
            #print('rand_top = ', end=' ')
            #print(rand_top)
            #graph_mat = AdjacencyMatrix(count_vertex, 0.2)#AdjacencyMatrix(count_vertex, 0.5)
            tree_1 = Tree(x[len(x)-1-i]+1)
            tree_2 = Tree(x[len(x)-1-i])

            centre_tree_1 = center_for_list(tree_1.list_tree.list_)
            if len(centre_tree_1) == 1:
              cent_1 += 1
            centre_tree_2 = center_for_list(tree_2.list_tree.list_)
            if len(centre_tree_2) == 1:
              cent_2 += 1

            centroid_tree_1 = centroid_for_list(tree_1.list_tree.list_)
            if len(centroid_tree_1) == 1:
              cend_1 += 1
            centroid_tree_2 = centroid_for_list(tree_2.list_tree.list_)
            if len(centroid_tree_2) == 1:
              cend_2 += 1      
        
        count_1_center[i] = cent_1
        count_2_center[i] = cent_2
        count_1_centroid[i] = cend_1
        count_2_centroid[i] = cend_2

    print(x)
    print('centre of 1 vertex нечет',count_1_center)
    print('centre of 1 vertex чет',count_2_center)
    print('centroid of 1 vertex нечет',count_1_centroid)
    print('centroid of 1 vertex чет', count_2_centroid)

    



if __name__ == "__main__":
    main()
# Out:
# Input count of iter number graph:
# 10
# iter -  1
# iter -  2
# iter -  3
# iter -  4
# iter -  5
# iter -  6
# iter -  7
# iter -  8
# iter -  9
# iter -  10
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
# centre of 1 vertex нечет [50, 96, 145, 204, 252, 299, 359, 391, 449, 487]
# centre of 1 vertex чет [46, 88, 150, 213, 242, 312, 370, 409, 466, 508]
# centroid of 1 vertex нечет [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
# centroid of 1 vertex чет [96, 193, 280, 365, 459, 543, 644, 708, 797, 849]

# %%
x = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
center_1 = [50, 96, 145, 204, 252, 299, 359, 391, 449, 487]
center_2 = [46, 88, 150, 213, 242, 312, 370, 409, 466, 508]
centroid_1 =  [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
centroid_2 = [96, 193, 280, 365, 459, 543, 644, 708, 797, 849]

# %%
two = [(x[i] - centroid_2[i])  for i in range(len(x))]

# %%
'odd number of vertices')
    rects2 = ax.bar(id + width/2, g2, width, label='even number of vertices')

# %%
    #plt.figure(figsize=(11,7))   
    plt.rc('legend', fontsize=16)
    
    #ax = plt.gca()
    fig, ax = plt.subplots(figsize=(10,8))
    g1 = centroid_2
    g2 = two
    width = 0.3
    id = np.arange(10)
    #fig, ax = plt.subplots()
    rects1 = ax.bar(id - width/2, g1, width, label='Centroid of 1 vertix')
    rects2 = ax.bar(id + width/2, g2, width, label='Centroid of 2 vertices')
    #ax.set_title('Пример групповой диаграммы')
    ax.set_xticks(id)
    ax.set_xticklabels(x, fontsize=16)
    #ax.hist([center_1,two],color=['b','r'])
    #ax.set_yticklabels(fontsize=16)
    
    #bfs = ax.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #dfs = ax.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    #bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='BFS-list', lw=2, ms=7)
    #dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='DFS-list', lw=2, ms=7)
    ax.set_ylabel('', fontsize = 15)
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    #plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    #plt.ylabel('Number of , sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of trees',fontsize=16, labelpad =12)
    #plt.grid(True)
    #plt.grid(which='major', linewidth = 1)
    #plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('The number of trees with a centroid of 1 or 2 vertex', fontsize=18, pad=15)    
    plt.legend(title ="An even number of vertices in the tree",title_fontsize=16)
    
    plt.show()

# %%
plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    dfs = ax.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='BFS-list', lw=2, ms=7)
    dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='DFS-list', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('BFS and DFS Algorithms on Adjacency List and Matrix', fontsize=18, pad=15)    
    plt.legend(title ="Graph density - 0.2",title_fontsize=16)
    
    plt.show()

# %% [markdown]
# #Центр и центроид

# %%
""" Main class """
import time
import matplotlib.pyplot as plt
import random


def main():

    print('Input count of iter: ')
    count = int(input())
    count_vertex = 250
    interval = 250
    x = [i for i in range(count_vertex, count*count_vertex+1, count_vertex)]
    #print(x)
    y_bfs_mat = [0 for i in range(count)]

    y_dfs_mat = [0 for i in range(count)]

    y_bfs_list = [0 for i in range(count)]

    y_dfs_list = [0 for i in range(count)]
    count_graph = 5

    for i in range(count):
        count_time_bfs_mat = 0
        count_time_dfs_mat = 0
        count_time_bfs_list = 0
        count_time_dfs_list = 0
        print('iter - ', i+1)
        for j in range(count_graph):
            #print('count_vertex =' ,count_vertex)
            rand_top = random.randint(0, count_vertex-1)
            #print('rand_top = ', end=' ')
            #print(rand_top)
            #graph = Tree(count_vertex)
            graph_mat = AdjacencyMatrix(count_vertex, 0.8)#AdjacencyMatrix(count_vertex, 0.5)
            graph_list = AdjacencyList(create=False)#AdjacencyList()
            graph_list.conversion_from_matrix_to_list(graph_mat.matrix)
            #print(graph_mat)
            #print(graph_list)

            bfs_center = bfs_for_list(graph_list.list_, rand_top)  # tree bfs

            start_time_bfs_mat = time.time()
            tree_bfs_mat = center_for_list(bfs_center)
            end_time_bfs_mat = time.time() - start_time_bfs_mat
            
            dfs_center = dfs_for_list(graph_list.list_, rand_top)   # tree dfs
 
            start_time_dfs_mat = time.time()
            tree_dfs_mat = center_for_list(dfs_center)            
            end_time_dfs_mat = time.time() - start_time_dfs_mat

            start_time_bfs_list = time.time()
            tree_list_bfs = centroid_for_list(bfs_center)
            end_time_bfs_list = time.time() - start_time_bfs_list

            start_time_dfs_list = time.time()
            tree_list_dfs = centroid_for_list(dfs_center)
            end_time_dfs_list = time.time() - start_time_dfs_list

            count_time_bfs_mat += end_time_bfs_mat
            count_time_dfs_mat += end_time_dfs_mat
            count_time_bfs_list += end_time_bfs_list
            count_time_dfs_list += end_time_dfs_list
        count_vertex += interval
        y_bfs_mat[i] = count_time_bfs_mat/count_graph
        y_dfs_mat[i] = count_time_dfs_mat/count_graph
        y_bfs_list[i] = count_time_bfs_list/count_graph
        y_dfs_list[i] = count_time_dfs_list/count_graph

    print('x = ', x)
    print('center_bfs = ',y_bfs_mat)
    print('center_dfs = ', y_dfs_mat)
    print('centroid_bfs = ', y_bfs_list)
    print('centroid_dfs = ', y_dfs_list)

    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, y_bfs_mat, 'o-r', label='Center-matrix', lw=2, ms=7)
    dfs = ax.plot(x, y_dfs_mat, 'o-b', label='Centroid-matrix', lw=2, ms=7)
    bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='Center-list', lw=2, ms=7)
    dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='Centroid-list', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center and Centroid Algorithms on Adjacency List and Matrix', fontsize=18, pad=15)    
    plt.legend(title ="Graph - Tree",title_fontsize=16)
    
    plt.show()



if __name__ == "__main__":
    main()
# Out:
# Input count of iter:
# 8
# iter -  1
# iter -  2
# iter -  3
# iter -  4
# iter -  5
# iter -  6
# iter -  7
# iter -  8
# x =  [250, 500, 750, 1000, 1250, 1500, 1750, 2000]
# center_bfs =  [0.0003132820129394531, 0.00042743682861328124, 0.000632476806640625, 0.0008725166320800781, 0.007082366943359375, 0.0015026092529296874, 0.0016385555267333985, 0.028400373458862305]
# center_dfs =  [0.003423309326171875, 0.01485438346862793, 0.03320589065551758, 0.06072707176208496, 0.11488685607910157, 0.14245963096618652, 0.21581006050109863, 0.2530850410461426]
# centroid_bfs =  [0.0022307872772216798, 0.007283067703247071, 0.017530012130737304, 0.030156469345092772, 0.05045018196105957, 0.07498798370361329, 0.10557126998901367, 0.157236909866333]
# centroid_dfs =  [0.162526273727417, 1.2062147617340089, 4.102602577209472, 9.824712038040161, 19.282852554321288, 35.21899061203003, 57.6980438709259, 91.44162349700927]

# %%
import time
import matplotlib.pyplot as plt
import random

# %%
#BFS_DFS_CENT_CEND 0.2

x =  [250, 500, 750, 1000, 1250, 1500, 1750, 2000]
center_bfs_1 =  [0.00023546218872070313, 0.00043625831604003905, 0.000664377212524414, 0.0009263038635253906, 0.0012586593627929687, 0.0014996528625488281, 0.0016819953918457032, 0.015314817428588867]
center_dfs_1 =  [0.0036095142364501952, 0.016110610961914063, 0.03355855941772461, 0.05992388725280762, 0.09884047508239746, 0.13932332992553711, 0.18783774375915527, 0.24676876068115233]
centroid_bfs_1 =  [0.017531919479370116, 0.07332377433776856, 0.1693510055541992, 0.29978022575378416, 0.5051714420318604, 0.6974620819091797, 0.9892820358276367, 1.3654064178466796]
centroid_dfs_1 =  [0.1336994171142578, 1.1546866416931152, 3.9238837242126463, 9.654709720611573, 19.0759117603302, 34.9686957359314, 56.63933773040772, 88.91586780548096]

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_bfs, 'o-r', label='Center-bfs-tree', lw=2, ms=7)
    dfs = ax.plot(x, center_dfs, 'o-b', label='Center-dfs-tree', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_bfs, 'o-g', label='Centroid-bfs-tree', lw=2, ms=7)
    dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center and Centroid Algorithms for BFS- n\' DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Graph density - 0.2",title_fontsize=16)
    
    plt.show()

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_bfs, 'o-r', label='Center-bfs-tree', lw=2, ms=7)
    dfs = ax.plot(x, center_dfs, 'o-b', label='Center-dfs-tree', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_bfs, 'o-g', label='Centroid-bfs-tree', lw=2, ms=7)
    #dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center and Centroid Algorithms for BFS- n\' DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Graph density - 0.2",title_fontsize=16)
    
    plt.show()

# %%
#BFS_DFS_TREE_CENT_CEND 0.5
x =  [250, 500, 750, 1000, 1250, 1500, 1750, 2000]
center_bfs_2 =  [0.00022029876708984375, 0.0004492282867431641, 0.0006880283355712891, 0.0009581565856933594, 0.0011837482452392578, 0.0014198780059814452, 0.001817798614501953, 0.022076177597045898]
center_dfs_2 =  [0.003458261489868164, 0.014440774917602539, 0.0338444709777832, 0.061667680740356445, 0.09413843154907227, 0.136372709274292, 0.18923492431640626, 0.2540407180786133]
centroid_bfs_2 =  [0.0045947074890136715, 0.021390390396118165, 0.051024007797241214, 0.08721857070922852, 0.1462873935699463, 0.2255164623260498, 0.29179987907409666, 0.3907681941986084]
centroid_dfs_2 =  [0.16279959678649902, 1.1979779720306396, 4.098793411254883, 9.785492181777954, 19.493164396286012, 34.82448787689209, 58.75434403419494, 92.00103726387024]

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_bfs, 'o-r', label='Center-bfs-tree', lw=2, ms=7)
    dfs = ax.plot(x, center_dfs, 'o-b', label='Center-dfs-tree', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_bfs, 'o-g', label='Centroid-bfs-tree', lw=2, ms=7)
    dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center and Centroid Algorithms for BFS- n\' DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Graph density - 0.5",title_fontsize=16)
    
    plt.show()

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_bfs, 'o-r', label='Center-bfs-tree', lw=2, ms=7)
    dfs = ax.plot(x, center_dfs, 'o-b', label='Center-dfs-tree', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_bfs, 'o-g', label='Centroid-bfs-tree', lw=2, ms=7)
    #dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center and Centroid Algorithms for BFS- n\' DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Graph density - 0.5",title_fontsize=16)
    
    plt.show()

# %%
# BFS_DFS_TREE_CENT_CEND 0.8

x =  [250, 500, 750, 1000, 1250, 1500, 1750, 2000]
center_bfs_3 =  [0.0003132820129394531, 0.00042743682861328124, 0.000632476806640625, 0.0008725166320800781, 0.007082366943359375, 0.0015026092529296874, 0.0016385555267333985, 0.028400373458862305]
center_dfs_3 =  [0.003423309326171875, 0.01485438346862793, 0.03320589065551758, 0.06072707176208496, 0.11488685607910157, 0.14245963096618652, 0.21581006050109863, 0.2530850410461426]
centroid_bfs_3 =  [0.0022307872772216798, 0.007283067703247071, 0.017530012130737304, 0.030156469345092772, 0.05045018196105957, 0.07498798370361329, 0.10557126998901367, 0.157236909866333]
centroid_dfs_3 =  [0.162526273727417, 1.2062147617340089, 4.102602577209472, 9.824712038040161, 19.282852554321288, 35.21899061203003, 57.6980438709259, 91.44162349700927]

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_bfs, 'o-r', label='Center-bfs-tree', lw=2, ms=7)
    dfs = ax.plot(x, center_dfs, 'o-b', label='Center-dfs-tree', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_bfs, 'o-g', label='Centroid-bfs-tree', lw=2, ms=7)
    dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center and Centroid Algorithms for BFS- n\' DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Graph density - 0.8",title_fontsize=16)
    
    plt.show()

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_bfs, 'o-r', label='Center-bfs-tree', lw=2, ms=7)
    dfs = ax.plot(x, center_dfs, 'o-b', label='Center-dfs-tree', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_bfs, 'o-g', label='Centroid-bfs-tree', lw=2, ms=7)
   # dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center and Centroid Algorithms for BFS- n\' DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Graph density - 0.8",title_fontsize=16)
    
    plt.show()

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_bfs_1, 'o-r', label='Center-bfs-tree 0.2', lw=2, ms=7)
    dfs = ax.plot(x, center_bfs_2, 'o-b', label='Center-bfs-tree 0.5', lw=2, ms=7)
    bfs_l = ax.plot(x, center_bfs_3, 'o-g', label='Center-bfs-tree 0.8', lw=2, ms=7)
   # dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center Algorithm for BFS--Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Center of Tree",title_fontsize=16)
    
    plt.show()

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_dfs_1, 'o-r', label='Center-dfs-tree 0.2', lw=2, ms=7)
    dfs = ax.plot(x, center_dfs_2, 'o-b', label='Center-dfs-tree 0.5', lw=2, ms=7)
    bfs_l = ax.plot(x, center_dfs_3, 'o-g', label='Center-dfs-tree 0.8', lw=2, ms=7)
   # dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('CenterAlgorithm for DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Center of Tree",title_fontsize=16)
    
    plt.show()

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, centroid_bfs_1, 'o-r', label='Centroid-bfs-tree 0.2', lw=2, ms=7)
    dfs = ax.plot(x, centroid_bfs_2, 'o-b', label='Centroid-bfs-tree 0.5', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_bfs_3, 'o-g', label='Centroid-bfs-tree 0.8', lw=2, ms=7)
   # dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Centroid Algorithm for BFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Centroid of Tree",title_fontsize=16)
    
    plt.show()

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, centroid_dfs_1, 'o-r', label='Centroid-dfs-tree 0.2', lw=2, ms=7)
    dfs = ax.plot(x, centroid_dfs_2, 'o-b', label='Centroid-dfs-tree 0.5', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_dfs_3, 'o-g', label='Centroid-dfs-tree 0.8', lw=2, ms=7)
   # dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Centroid Algorithm for DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Centroid of Tree",title_fontsize=16)
    
    plt.show()

# %% [markdown]
# # Шарниры гистограмма

# %%
""" Main class """
import time
import matplotlib.pyplot as plt
import random


def main():

    print('Input count of iter number graph: ')
    count = int(input())
    count_vertex = 100
    interval = 100
    x = [i for i in range(count_vertex, count*count_vertex+1, count_vertex)]   #[100,200,...]
    #print(x)
    count_1_center = [0 for i in range(count)]

    count_2_center = [0 for i in range(count)]

   # count_1_centroid = [0 for i in range(count)]

   # count_2_centroid = [0 for i in range(count)]
    prob = 0.005
    
    #count_graph = 10

    for i in range(count):
        
        cent_1 = 0
        cent_2 = 0
        #cend_1 = 0
        #cend_2 = 0

        print('iter - ', i+1)
        for j in range(x[i]):
            #print('count_vertex =' ,count_vertex)
            rand_top = random.randint(0, count_vertex-1)
            #print('rand_top = ', end=' ')
            #print(rand_top)
            graph_mat_1 = AdjacencyList(count_vertex+1, prob)#AdjacencyMatrix(count_vertex, 0.5)
            #tree_1 = Tree(x[len(x)-1-i]+1)
            #tree_2 = Tree(x[len(x)-1-i])
            graph_mat_2 = AdjacencyList(count_vertex, prob)

            centre_tree_1 = cut_vertex_for_list(graph_mat_1.list_, rand_top)
            if len(centre_tree_1) == 0:
              cent_1 += 1
            centre_tree_2 = cut_vertex_for_list(graph_mat_2.list_, rand_top)
            if len(centre_tree_2) == 0:
              cent_2 += 1

               
        
        count_1_center[i] = cent_1
        count_2_center[i] = cent_2
        #count_1_centroid[i] = cend_1
        #count_2_centroid[i] = cend_2

    print('x',x)
    print('odd_cut_none',count_1_center)
    print('even_cut_none',count_2_center)
    #print('centroid of 1 vertex нечет',count_1_centroid)
    #print('centroid of 1 vertex чет', count_2_centroid)

    



if __name__ == "__main__":
    main()
# Out:
# Input count of iter number graph:
# 10
# iter -  1
# iter -  2
# iter -  3
# iter -  4
# iter -  5
# iter -  6
# iter -  7
# iter -  8
# iter -  9
# iter -  10
# x [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
# odd_cut_none [14, 34, 59, 73, 73, 94, 99, 134, 164, 145]
# even_cut_none [14, 22, 44, 60, 82, 101, 103, 112, 133, 145]

# %%
#0.1
x = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
odd_cut_none = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
even_cut_none = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

# %%
#0.05
x = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
odd_cut_none = [99, 198, 294, 395, 494, 597, 688, 794, 894, 992]
even_cut_none = [98, 199, 299, 394, 493, 597, 696, 788, 885, 989]

# %%
#0.01
x = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
odd_cut_none = [32, 83, 117, 146, 183, 210, 298, 307, 363, 413]
even_cut_none = [40, 77, 113, 156, 194, 227, 284, 327, 320, 402]

# %%
# 0.005
x = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
odd_cut_none = [14, 34, 59, 73, 73, 94, 99, 134, 164, 145]
even_cut_none  = [14, 22, 44, 60, 82, 101, 103, 112, 133, 145]

# %%
two = [(x[i] - odd_cut_none[i])  for i in range(len(x))]

# %%
    #plt.figure(figsize=(11,7))   
    plt.rc('legend', fontsize=16)
    
    #ax = plt.gca()
    fig, ax = plt.subplots(figsize=(10,8))
    g1 = odd_cut_none
    g2 = two
    width = 0.3
    id = np.arange(10)
    #fig, ax = plt.subplots()
    rects1 = ax.bar(id - width/2, g1, width, label='No cut vertex')
    rects2 = ax.bar(id + width/2, g2, width, label='There is cut vertex')
    #ax.set_title('Пример групповой диаграммы')
    ax.set_xticks(id)
    ax.set_xticklabels(x, fontsize=16)
    #ax.hist([center_1,two],color=['b','r'])
    #ax.set_yticklabels(fontsize=16)
    
    #bfs = ax.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #dfs = ax.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    #bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='BFS-list', lw=2, ms=7)
    #dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='DFS-list', lw=2, ms=7)
    ax.set_ylabel('', fontsize = 15)
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    #plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    #plt.ylabel('Number of , sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of graphs',fontsize=16, labelpad =12)
    #plt.grid(True)
    #plt.grid(which='major', linewidth = 1)
    #plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('The presence of cut vertix in the graphs', fontsize=18, pad=15)    
    plt.legend(title ="An odd number of vertices in the graph. Graph density - 0.05",title_fontsize=16)
    
    plt.show()

# %%
    #plt.figure(figsize=(11,7))   
    plt.rc('legend', fontsize=16)
    
    #ax = plt.gca()
    fig, ax = plt.subplots(figsize=(10,8))
    g1 = odd_cut_none
    g2 = two
    width = 0.3
    id = np.arange(10)
    #fig, ax = plt.subplots()
    rects1 = ax.bar(id - width/2, g1, width, label='No cut vertex')
    rects2 = ax.bar(id + width/2, g2, width, label='There is cut vertex')
    #ax.set_title('Пример групповой диаграммы')
    ax.set_xticks(id)
    ax.set_xticklabels(x, fontsize=16)
    #ax.hist([center_1,two],color=['b','r'])
    #ax.set_yticklabels(fontsize=16)
    
    #bfs = ax.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #dfs = ax.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    #bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='BFS-list', lw=2, ms=7)
    #dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='DFS-list', lw=2, ms=7)
    ax.set_ylabel('', fontsize = 15)
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    #plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    #plt.ylabel('Number of , sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of graphs',fontsize=16, labelpad =12)
    #plt.grid(True)
    #plt.grid(which='major', linewidth = 1)
    #plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('The presence of cut vertix in the graphs', fontsize=18, pad=15)    
    plt.legend(title ="An odd number of vertices in the graph. Graph density - 0.01",title_fontsize=16)
    
    plt.show()

# %%
    #plt.figure(figsize=(11,7))   
    plt.rc('legend', fontsize=16)
    
    #ax = plt.gca()
    fig, ax = plt.subplots(figsize=(10,8))
    g1 = odd_cut_none
    g2 = two
    width = 0.3
    id = np.arange(10)
    #fig, ax = plt.subplots()
    rects1 = ax.bar(id - width/2, g1, width, label='No cut vertex')
    rects2 = ax.bar(id + width/2, g2, width, label='There is cut vertex')
    #ax.set_title('Пример групповой диаграммы')
    ax.set_xticks(id)
    ax.set_xticklabels(x, fontsize=16)
    #ax.hist([center_1,two],color=['b','r'])
    #ax.set_yticklabels(fontsize=16)
    
    #bfs = ax.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #dfs = ax.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    #bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='BFS-list', lw=2, ms=7)
    #dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='DFS-list', lw=2, ms=7)
    ax.set_ylabel('', fontsize = 15)
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    #plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    #plt.ylabel('Number of , sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of graphs',fontsize=16, labelpad =12)
    #plt.grid(True)
    #plt.grid(which='major', linewidth = 1)
    #plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('The presence of cut vertix in the graphs', fontsize=18, pad=15)    
    plt.legend(title ="An odd number of vertices in the graph. Graph density - 0.005",title_fontsize=16)
    
    plt.show()

# %%
    #plt.figure(figsize=(11,7))   
    plt.rc('legend', fontsize=16)
    
    #ax = plt.gca()
    fig, ax = plt.subplots(figsize=(10,8))
    g1 = odd_cut_none
    g2 = two
    width = 0.3
    id = np.arange(10)
    #fig, ax = plt.subplots()
    rects1 = ax.bar(id - width/2, g1, width, label='No cut vertex')
    rects2 = ax.bar(id + width/2, g2, width, label='There is cut vertex')
    #ax.set_title('Пример групповой диаграммы')
    ax.set_xticks(id)
    ax.set_xticklabels(x, fontsize=16)
    #ax.hist([center_1,two],color=['b','r'])
    #ax.set_yticklabels(fontsize=16)
    
    #bfs = ax.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #dfs = ax.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    #bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='BFS-list', lw=2, ms=7)
    #dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='DFS-list', lw=2, ms=7)
    ax.set_ylabel('', fontsize = 15)
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    #plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    #plt.ylabel('Number of , sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of graphs',fontsize=16, labelpad =12)
    #plt.grid(True)
    #plt.grid(which='major', linewidth = 1)
    #plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('The presence of cut vertix in the graphs', fontsize=18, pad=15)    
    plt.legend(title ="An even number of vertices in the graph. Graph density - 0.05",title_fontsize=16)
    
    plt.show()

# %% [markdown]
# #Блоки BFS и DFS

# %%
""" Main class """
import time
import matplotlib.pyplot as plt
import random


def main():

    print('Input count of iter: ')
    count = int(input())
    count_vertex = 250
    interval = 250
    x = [i for i in range(count_vertex, count*count_vertex+1, count_vertex)]
    #print(x)
    y_bfs_mat = [0 for i in range(count)]

    y_dfs_mat = [0 for i in range(count)]

    y_bfs_list = [0 for i in range(count)]

    y_dfs_list = [0 for i in range(count)]
    count_graph = 5

    for i in range(count):
        count_time_bfs_mat = 0
        count_time_dfs_mat = 0
        count_time_bfs_list = 0
        count_time_dfs_list = 0
        print('iter - ', i+1)
        for j in range(count_graph):
            #print('count_vertex =' ,count_vertex)
            rand_top = random.randint(0, count_vertex-1)
            #print('rand_top = ', end=' ')
            #print(rand_top)
            #graph = Tree(count_vertex)
            graph_mat = AdjacencyMatrix(count_vertex, 0.2)#AdjacencyMatrix(count_vertex, 0.5)
            graph_list = AdjacencyList(create=False)#AdjacencyList()
            graph_list.conversion_from_matrix_to_list(graph_mat.matrix)
            #print(graph_mat)
            #print(graph_list)

            bfs_center = bfs_for_list(graph_list.list_, 7)  # tree bfs

            start_time_bfs_mat = time.time()
            tree_bfs_mat, cut_1 = blocks_for_list(bfs_center)
            end_time_bfs_mat = time.time() - start_time_bfs_mat
            
            dfs_center = dfs_for_list(graph_list.list_, 7)   # tree dfs
 
            start_time_dfs_mat = time.time()
            tree_dfs_mat, cut_2 = blocks_for_list(dfs_center)            
            end_time_dfs_mat = time.time() - start_time_dfs_mat

            start_time_bfs_list = time.time()
            #tree_list_bfs = centroid_for_list(bfs_center)
            end_time_bfs_list = time.time() - start_time_bfs_list

            start_time_dfs_list = time.time()
            #tree_list_dfs = centroid_for_list(dfs_center)
            end_time_dfs_list = time.time() - start_time_dfs_list

            count_time_bfs_mat += end_time_bfs_mat
            count_time_dfs_mat += end_time_dfs_mat
            #count_time_bfs_list += end_time_bfs_list
            #count_time_dfs_list += end_time_dfs_list
        count_vertex += interval
        y_bfs_mat[i] = count_time_bfs_mat/count_graph
        y_dfs_mat[i] = count_time_dfs_mat/count_graph
       # y_bfs_list[i] = count_time_bfs_list/count_graph
       # y_dfs_list[i] = count_time_dfs_list/count_graph

    print('x = ', x)
    print('center_bfs = ',y_bfs_mat)
    print('center_dfs = ', y_dfs_mat)
   # print('centroid_bfs = ', y_bfs_list)
   # print('centroid_dfs = ', y_dfs_list)

    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, y_bfs_mat, 'o-r', label='Center-matrix', lw=2, ms=7)
    dfs = ax.plot(x, y_dfs_mat, 'o-b', label='Centroid-matrix', lw=2, ms=7)
   # bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='Center-list', lw=2, ms=7)
   # dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='Centroid-list', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center Algorithm on Adjacency List and Matrix', fontsize=18, pad=15)    
    plt.legend(title ="Graph - Tree",title_fontsize=16)
    
    plt.show()



if __name__ == "__main__":
    main()
# Out:
# Input count of iter:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...

# %%
    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, center_bfs, 'o-r', label='Center-bfs-tree', lw=2, ms=7)
    dfs = ax.plot(x, center_dfs, 'o-b', label='Center-dfs-tree', lw=2, ms=7)
    bfs_l = ax.plot(x, centroid_bfs, 'o-g', label='Centroid-bfs-tree', lw=2, ms=7)
    dfs_l = ax.plot(x, centroid_dfs, 'o-m', label='Centroid-dfs-tree', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center Algorithm for BFS- n\' DFS-Tree on Adjacency List', fontsize=18, pad=15)    
    plt.legend(title ="Graph density - 0.2",title_fontsize=16)
    
    plt.show()

# %%
# center centroid matrix list
x = [500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
y_bfs_mat = [0.013488459587097167, 0.06391754150390624, 0.15018906593322753, 0.2682992696762085, 0.4262951135635376, 0.6204435348510742, 0.8824221611022949, 1.1264461040496827, 1.4459773778915406, 1.8548006057739257]
y_dfs_mat = [0.6449066400527954, 4.511264848709106, 11.922646093368531, 15.792676830291748, 35.61297233104706, 56.835571146011354, 92.42331943511962, 123.67126522064208, 248.20892841815947, 283.5594080686569]
y_bfs_list = [0.001703500747680664, 0.005227422714233399, 0.011435198783874511, 0.0421506404876709, 0.01725947856903076, 0.023259878158569336, 0.053056192398071286, 0.06138789653778076, 0.04137818813323975, 0.0499403715133667]
y_dfs_list = [0.07980525493621826, 0.5734868288040161, 1.5214796543121338, 2.0086915731430053, 4.474901151657105, 7.285399580001831, 11.809182858467102, 15.971189188957215, 32.7506160736084, 36.7056521654129]

# %%
    print(x)
    print(y_bfs_mat)
    print(y_dfs_mat)
    print(y_bfs_list)
    print(y_dfs_list)

    plt.figure(figsize=(13,9))   
    plt.rc('legend', fontsize=16)
    #plt.rc('axis', fontsize=16)
    #plt.legend()
    
    #plt.plot(x, y_bfs_mat, 'o-r', label='BFS-matrix', lw=2, ms=7)
    #plt.plot(x, y_dfs_mat, 'o-b', label='DFS-matrix', lw=2, ms=7)
    ax = plt.gca()
    #ax.axhline(y=0, color='k')
    #plt.plot([], [], ' ', label="Graph density - 0.2")
    bfs = ax.plot(x, y_bfs_mat, 'o-r', label='Center-matrix', lw=2, ms=7)
    #dfs = ax.plot(x, y_dfs_mat, 'o-b', label='Centroid-matrix', lw=2, ms=7)
    bfs_l = ax.plot(x, y_bfs_list, 'o-g', label='Center-list', lw=2, ms=7)
    #dfs_l = ax.plot(x, y_dfs_list, 'o-m', label='Centroid-list', lw=2, ms=7)
    #ax.set_xticks(x)
    #plt.plot(x, y_bfs_list, 'm', label='old')
    #plt.plot(x, y_dfs_list, 'g', label='2')
    #plt.plot(x, y_dfs_list, 'g', label='DFS-list')
    
    #plt.plot([], [], ' ', label="dgfgfjgkhj")
    plt.minorticks_on()
    plt.tick_params(axis='both', which='major', labelsize=16) 
    plt.ylabel('Time, sec ', fontsize=16, labelpad =12)
    plt.xlabel('Number of vertices',fontsize=16, labelpad =12)
    plt.grid(True)
    plt.grid(which='major', linewidth = 1)
    plt.grid(which='minor', linestyle=':')
    plt.tight_layout()
    plt.title('Center Algorithm on Adjacency List and Matrix', fontsize=18, pad=15)    
    plt.legend(title ="Graph - Tree",title_fontsize=16)
    
    plt.show()
# Out:
# [500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
# [0.013488459587097167, 0.06391754150390624, 0.15018906593322753, 0.2682992696762085, 0.4262951135635376, 0.6204435348510742, 0.8824221611022949, 1.1264461040496827, 1.4459773778915406, 1.8548006057739257]
# [0.6449066400527954, 4.511264848709106, 11.922646093368531, 15.792676830291748, 35.61297233104706, 56.835571146011354, 92.42331943511962, 123.67126522064208, 248.20892841815947, 283.5594080686569]
# [0.001703500747680664, 0.005227422714233399, 0.011435198783874511, 0.0421506404876709, 0.01725947856903076, 0.023259878158569336, 0.053056192398071286, 0.06138789653778076, 0.04137818813323975, 0.0499403715133667]
# [0.07980525493621826, 0.5734868288040161, 1.5214796543121338, 2.0086915731430053, 4.474901151657105, 7.285399580001831, 11.809182858467102, 15.971189188957215, 32.7506160736084, 36.7056521654129]
